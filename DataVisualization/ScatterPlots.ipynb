# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
insurance_filepath = "/Users/yuna/Documents/GitHub/AcademicSemester2/resources/insurance.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# To create a simple scatter plot, we use the sns.scatterplot command and specify the values for:
# 1. the horizontal x-axis (x=insurance_data['bmi']), and
# 2. the vertical y-axis (y=insurance_data['charges']).

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# The scatterplot above suggests that body mass index(BMI) and insurance charges are positively corrected, where customers wth higher BMI typically also tend to pay more in insurance costs. (This pattern makes sense, since high BMI is typically associated with higher risk of coronic disease.)
#
# To double-check the strrngth of this relationship, you mignt like to add a regression line, or the line that best fits the data. We do this by changing the command to sns.regplot.

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# Color-coded scatter plots

# %% [markdown]
# We can use scatter plots to display the relationships between(not two, but...) three variables! One way of doing this is by color-coding the points.
#
# For instance, to understand how smoking affects the relationship between BMI and insurance costs, we can color-code the points by 'smoker', and plot the other two columns('bmi', 'charges') on the axes.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# This scatter plot shows that while nonsmokers to pay slightly more with increasing BMI, smokers pay MUCH more.
#
# To further emphasize this fact, we can use the sns.lmplot command to add two regression lines, corresponding to smokers and nonsmokers. (You'll notice that the regression line for smokers has a much steeper slope, relative to the line for nonsmokers!)

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %% [markdown]
# Both sns.regplot and sns.lmplot are functions in the Seaborn library that are used for creating scatter plots with regression lines, but they have some differences in terms of their intended use and capabilities.
#
# sns.regplot:
# Use Case: regplot is generally used for creating a scatter plot with a linear regression line fit through the data.
# Functionality: It can create a scatter plot with a linear regression line and optionally display a confidence interval around the regression line.
# Parameters: You pass the data directly as arguments to x and y.
# 用例：regplot 通常用于创建具有拟合数据的线性回归线的散点图。
# 功能：它可以创建带有线性回归线的散点图，并可选择显示回归线周围的置信区间。
# 参数：将数据作为参数直接传递给 x 和 y。
#
# sns.lmplot:
# Use Case: lmplot is more versatile and is designed for more complex scenarios. It is primarily intended for plotting linear regression models on different subsets of the dataset.
# Functionality: In addition to scatter plots with regression lines, lmplot can create multiple plots (facets) based on additional categorical variables, such as the hue parameter in your example.
# Parameters: You pass the data using the data parameter and specify the column names for x and y.
# 用例：lmplot 更加通用，专为更复杂的场景而设计。 它主要用于在数据集的不同子集上绘制线性回归模型。
# 功能：除了带有回归线的散点图之外，lmplot 还可以根据其他分类变量（例如示例中的色调参数）创建多个图（方面）。
# 参数：您可以使用 data 参数传递数据并指定 x 和 y 的列名称。

# %% [markdown]
# The sns.lmplot command above works slightly differently than the commands you have learned about so far:
# 1. Instead of setting x=insurance_data['bmi'] to select the 'bmi' column in insurance_data, we set x="bmi" to specify the name of the column only.
#
# 2. Similarly, y="charges" and hue="smoker" also contain the names of columns.
#
# 3. We specify the dataset with data=insurance_data.
#
# Finally, there's one more plot that you'll learn about, that might look slightly different from how you're used to seeing scatter plots. Usually, we use scatter plots to highlight the relationship between two continuous variables (like 'bmi' and 'charges').
# However, we can adapt the design of the scatter plot to feature a categorical variable (like 'smoker') on one of the main axes. We'll refer to this plot type as a categorical scatter plot, and we build it with the sns.swarmplot command.
# 但是，我们可以调整散点图的设计，以在主轴之一上显示分类变量（例如“吸烟者”）。 我们将这种绘图类型称为分类散点图，并使用 sns.swarmplot 命令构建它。

# %%
sns.swarmplot(x=insurance_data['smoker'],
                y=insurance_data['charges'])
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# /opt/homebrew/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Among other things, this plot shows us that:
#
# 1. on average, non-smokers are charged less than smokers, and
# 2. the customers who pay the most are smokers; whereas the customers who pay the least are non-smokers.
